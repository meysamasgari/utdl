# %%
from pytube import Playlist
p = Playlist('https://www.youtube.com/playlist?list=PL5HoEgayCLAZuEbkP5PBSKmFljLIV8yxf')

print(f'Downloading: {p.title}')

for video in p.videos:
    print(video.title)
    # st = video.streams.get_highest_resolution()
    st = video.streams.get_by_resolution("720p")
    st.download()
    #video.streams.first().download()
# Out:
# Downloading: آموزش گیتار کلاسیک، پاپ
# آموزش گیتار کلاسیک، پاپ؛ از صفر، جلسه 4
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /Users/meisamasgri/Documents/Projects/ytube_downloader/ytube_downloader.ipynb Cell 1 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/meisamasgri/Documents/Projects/ytube_downloader/ytube_downloader.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> # st = video.streams.get_highest_resolution()
#       <a href='vscode-notebook-cell:/Users/meisamasgri/Documents/Projects/ytube_downloader/ytube_downloader.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> st = video.streams.get_by_resolution("720p")
# ---> <a href='vscode-notebook-cell:/Users/meisamasgri/Documents/Projects/ytube_downloader/ytube_downloader.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> st.download()
#
# ...

# %%
from pytube import YouTube

yt = YouTube('https://www.youtube.com/watch?v=iqQgED9vV7k&list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO&index=7').streams.first().download()
# yt = YouTube("")
yt = yt.get('mp4', '720p')
# yt.download('/path/to/download/directory')
yt.download()
yt.captions.all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 5>()
#       3 yt = YouTube('https://www.youtube.com/watch?v=iqQgED9vV7k&list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO&index=7').streams.first().download()
#       4 # yt = YouTube("")
# ----> 5 yt = yt.get('mp4', '720p')
#       6 # yt.download('/path/to/download/directory')
#       7 yt.download()
#
# AttributeError: 'str' object has no attribute 'get'

# %%
# from pytube4 import YouTube
# YouTube('https://www.youtube.com/watch?v=iqQgED9vV7k&list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO&index=7').streams.get_highest_resolution().download()
 # >>>
 # >>> yt = YouTube('http://youtube.com/watch?v=9bZkp7q19f0')
 # >>> yt.streams
 #  ... .filter(progressive=True, file_extension='mp4')
 #  ... .order_by('resolution')[-1]
 #  ... .download()

# %%
from pytube import YouTube
YouTube('https://www.youtube.com/watch?v=yDL5AmERS9I&list=PL5HoEgayCLAZuEbkP5PBSKmFljLIV8yxf&index=5').streams.get_by_resolution("720p").download()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/meisamasgri/Documents/Projects/ytube_downloader/ytube_downloader.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/meisamasgri/Documents/Projects/ytube_downloader/ytube_downloader.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from pytube import YouTube
# ----> <a href='vscode-notebook-cell:/Users/meisamasgri/Documents/Projects/ytube_downloader/ytube_downloader.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> YouTube('https://www.youtube.com/watch?v=yDL5AmERS9I&list=PL5HoEgayCLAZuEbkP5PBSKmFljLIV8yxf&index=5').streams.get_by_resolution("720p").download()
#
# File ~/Documents/Projects/ytube_downloader/.venv/lib/python3.9/site-packages/pytube/streams.py:247, in Stream.download(self, output_path, filename, filename_prefix, skip_existing, timeout, max_retries)
#     244     self.on_complete(file_path)
# ...

# %%
import youtube_dl
# import os

ydl_opts = {}
# os.chdir('/Users/meisamasgri/Documents')
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download(['https://www.youtube.com/watch?v=yDL5AmERS9I&list=PL5HoEgayCLAZuEbkP5PBSKmFljLIV8yxf&index=5'])
# Out:
# [youtube:tab] Downloading playlist PL5HoEgayCLAZuEbkP5PBSKmFljLIV8yxf - add --no-playlist to just download video yDL5AmERS9I
# [youtube:tab] PL5HoEgayCLAZuEbkP5PBSKmFljLIV8yxf: Downloading webpage
# [youtube:tab] PL5HoEgayCLAZuEbkP5PBSKmFljLIV8yxf: Downloading webpage
# [download] Downloading playlist: آموزش گیتار کلاسیک، پاپ
# [youtube:tab] playlist آموزش گیتار کلاسیک، پاپ: Downloading 35 videos
# [download] Downloading video 1 of 35
# [youtube] ToPNUjrfw54: Downloading webpage
# ERROR: Unable to extract uploader id; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# ---------------------------------------------------------------------------
# RegexNotFoundError                        Traceback (most recent call last)
# ...

# %%
from numpy.random import seed
from numpy.random import randn
from scipy.stats import wilcoxon
# seed the random number generator
seed(1)
# generate two independent samples
data1 = 5 * randn(100) + 50
data2 = 5 * randn(100) + 51
# compare samples
stat, p = wilcoxon(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
